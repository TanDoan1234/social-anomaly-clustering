# %% [markdown]
# # 02. Preprocessing & Feature Engineering
# ---
# ## 🎯 Objective
# Clean the raw data and transform it into a format suitable for clustering algorithms.
#
# ## 📋 Table of Contents
# 1. [Data Cleaning](#1.-Data-Cleaning)
# 2. [Feature Transformation](#2.-Feature-Transformation)
# 3. [Feature Scaling](#3.-Feature-Scaling)
# 4. [Exporting Processed Data](#4.-Exporting-Processed-Data)

# %% [markdown]
# ## 1. Data Cleaning
# - Dropping irrelevant columns.
# - Handling outliers.

# %% [markdown]
# ## 2. Feature Transformation
# - Creating `follower_following_ratio`.
# - Encoding `is_verified`.

# %% [markdown]
# ## 3. Feature Scaling
# Using `StandardScaler` to normalize feature ranges.

# %% [markdown]
# ## 4. Exporting Processed Data
# Saving results to `datasets/processed/`.
