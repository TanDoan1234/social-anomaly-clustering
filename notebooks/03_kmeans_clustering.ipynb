# %% [markdown]
# # 03. K-Means Clustering
# ---
# ## 🎯 Objective
# Apply K-Means clustering to partition users into distinct behavioral groups.
#
# ## 📋 Table of Contents
# 1. [Elbow Method](#1.-Elbow-Method)
# 2. [Model Training](#2.-Model-Training)
# 3. [Cluster Profiling](#3.-Cluster-Profiling)
# 4. [Saving the Model](#4.-Saving-the-Model)

# %% [markdown]
# ## 1. Elbow Method
# Finding the optimal number of clusters `k`.

# %% [markdown]
# ## 2. Model Training
# Fitting K-Means to our scaled data.

# %% [markdown]
# ## 3. Cluster Profiling
# Analyzing the centroids of each cluster.
