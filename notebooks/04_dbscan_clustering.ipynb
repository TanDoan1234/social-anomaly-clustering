# %% [markdown]
# # 04. DBSCAN Clustering (Anomaly Detection)
# ---
# ## 🎯 Objective
# Use Density-Based Spatial Clustering of Applications with Noise (DBSCAN) to identify anomalies (bots) as outliers.
#
# ## 📋 Table of Contents
# 1. [Hyperparameter Tuning (Eps & MinSamples)](#1.-Hyperparameter-Tuning)
# 2. [Running DBSCAN](#2.-Running-DBSCAN)
# 3. [Identifying Noise (Anomalies)](#3.-Identifying-Noise)
# 4. [Comparison with K-Means](#4.-Comparison-with-K-Means)

# %% [markdown]
# ## 1. Hyperparameter Tuning
# Selecting appropriate density parameters.

# %% [markdown]
# ## 2. Running DBSCAN

# %% [markdown]
# ## 3. Identifying Noise (Anomalies)
# DBSCAN labels noise as `-1`.
