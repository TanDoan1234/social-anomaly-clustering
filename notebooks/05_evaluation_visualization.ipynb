# %% [markdown]
# # 05. Evaluation & Visualization
# ---
# ## 🎯 Objective
# Final evaluation of clustering results and visualization for reporting.
#
# ## 📋 Table of Contents
# 1. [PCA Visualization (2D/3D)](#1.-PCA-Visualization)
# 2. [Silhouette Score Comparison](#2.-Silhouette-Score-Comparison)
# 3. [Cluster Characteristic Analysis](#3.-Cluster-Characteristic-Analysis)
# 4. [Final Insights](#4.-Final-Insights)

# %% [markdown]
# ## 1. PCA Visualization
# Projecting high-dimensional data into 2D space.

# %% [markdown]
# ## 2. Silhouette Score Comparison

# %% [markdown]
# ## 3. Cluster Characteristic Analysis
# What defines a bot in this dataset?
